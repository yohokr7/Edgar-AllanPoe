# %%
import pandas as pd
import os
import bs4
import pickle
import requests
from bs4 import BeautifulSoup
import sys

# %%
company_list = ['Apple', 'Microsoft']
years = ['2014', '2015', '2016', '2017']

# %%
#DO NOT NEED TO RUN: CSV Already Created
#Found at https://pythonprogramming.net/sp500-company-list-python-programming-for-finance/
#I added more lists to obtain the Company name and CIK numbers, then combined into a DataFrame and Exported it out

resp = requests.get('http://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
soup = bs4.BeautifulSoup(resp.text, 'lxml')
table = soup.find('table', {'class': 'wikitable sortable'})

key_path = os.path.join('..','Financials', 'Ticker_and_CIK', 'Key.csv')

stock_tickers = []
companies = []
central_index_keys = []

for sp_row in table.findAll('tr')[1:]:
    stock_ticker = sp_row.findAll('td')[0].text
    stock_tickers.append(stock_ticker.rstrip())
    company = sp_row.findAll('td')[1].text
    companies.append(company.rstrip())
    central_index_key = sp_row.findAll('td')[7].text
    central_index_keys.append(central_index_key.rstrip())

sp500_df = pd.DataFrame(list(zip(stock_tickers, companies, central_index_keys)), columns = ["Ticker", "Company", "CIK"])
sp500_df.to_csv(key_path, index = False)

# %%
key_path = os.path.join('..','Financials', 'Ticker_and_CIK', 'Key.csv')

key_df = pd.read_csv(key_path)

key_dict = {}

for query in range(len(company_list)):
    try:
        company_df = key_df[key_df['Company'].str.contains(company_list[query].title())]
        key_dict[company_df.iloc[0, 1]] = [company_df.iloc[0, 0], company_df.iloc[0, 2]]
    except IndexError:
        print(f"{company_list[query]} could not be found")

if key_dict == {}:
    print ("Whoops, none of your companies were on the S&P 500. Please try again!")
else:
    print (f"Success! We were able to find {len(key_dict.keys())} of your queries in the S&P 500")
    print (f"We found: {list(key_dict.keys())} in the S&P 500")
# Out:
# Success! We were able to find 2 of your queries in the S&P 500
# We found: ['Apple Inc.', 'Microsoft Corp.'] in the S&P 500

# %%
#Unmodified Base Code found at https://www.codeproject.com/Articles/1227765/Parsing-XBRL-with-Python
#I added the ability for the code to query through a list of companies for multiple years and multiple quarters
#and save th


for companies_found in range(len(key_dict.keys())):
    company_name = list(key_dict.keys())[companies_found]
    ticker = key_dict.get(company_name)[0]
    
    cik = key_dict.get(company_name)[1]
    type = '10-Q'
    dateb = f'{years[-1]}-12-31'
    
    # Obtain HTML for search page
    base_url = "https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={}&type={}&dateb={}"
    edgar_resp = requests.get(base_url.format(cik, type, dateb))
    edgar_str = edgar_resp.text
    
    # Find the document link
    soup = BeautifulSoup(edgar_str, 'html.parser')
    table_tag = soup.find('table', class_='tableFile2')
    rows = table_tag.find_all('tr')
    
    doc_links = []
    dates = []
    
    for year in years:
        for row in rows:
            cells = row.find_all('td')
            if len(cells) > 3:
                if year in cells[3].text:
                    link = 'https://www.sec.gov' + cells[1].a['href']
                    file_date = cells[3].text
                    
                    doc_links.append(link)
                    dates.append(file_date)
                    
    for doc_link in range(len(doc_links)):
        # Obtain HTML for document page
        doc_resp = requests.get(doc_links[doc_link])
        doc_str = doc_resp.text
        # Find the XBRL link
        xbrl_link = ''
        soup = BeautifulSoup(doc_str, 'html.parser')
        table_tag = soup.find('table', class_='tableFile', summary='Data Files')
        rows = table_tag.find_all('tr')
        for row in rows:
            cells = row.find_all('td')
            if len(cells) > 3:
                if 'INS' in cells[3].text:
                    xbrl_link = 'https://www.sec.gov' + cells[2].a['href']
        # Obtain XBRL text from document
        xbrl_resp = requests.get(xbrl_link)
        xbrl_str = xbrl_resp.text
        # Find and print stockholder's equity
        soup = BeautifulSoup(xbrl_str, 'lxml')
        tag_list = soup.find_all()

        test = pd.DataFrame()

        for tag in tag_list:


            #Modified from the original; The original searched through to find specific line items
            #Modified to search through every 10-Q per given year, and extract any financial line item into its own 10-Q

            if tag.name.find('us-gaap:') != -1:
                try: 
                    if float(tag.text) > 0:
                        i = [f'{tag.name}', tag.text]
                        i_series = pd.Series(i)
                        test = test.append(i_series, ignore_index = True)
                except ValueError:
                    pass

        folder_path = os.path.join('..','Financials','10-Qs',f'{ticker}')
        file_path = os.path.join('..','Financials','10-Qs',f'{ticker}', f'{ticker}_{dates[doc_link]}.csv')

        try:
            os.mkdir(folder_path)
        except FileExistsError:
            pass

        test.to_csv(file_path, index = False)
# Out:
# 2017-12-31

# %%
#Found at https://www.codeproject.com/Articles/1227765/Parsing-XBRL-with-Python

# Access page
cik = '320193'
type = '10-Q'
dateb = '20160101'
# Obtain HTML for search page
base_url = "https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={}&type={}&dateb={}"
edgar_resp = requests.get(base_url.format(cik, type, dateb))
edgar_str = edgar_resp.text
# Find the document link
doc_link = ''
soup = BeautifulSoup(edgar_str, 'html.parser')
table_tag = soup.find('table', class_='tableFile2')
rows = table_tag.find_all('tr')
for row in rows:
    cells = row.find_all('td')
    if len(cells) > 3:

        print(cells[3])

        if '2015' in cells[3].text:
            doc_link = 'https://www.sec.gov' + cells[1].a['href']
# Exit if document link couldn't be found
if doc_link == '':
    print("Couldn't find the document link")
    sys.exit()
# Obtain HTML for document page
doc_resp = requests.get(doc_link)
doc_str = doc_resp.text
# Find the XBRL link
xbrl_link = ''
soup = BeautifulSoup(doc_str, 'html.parser')
table_tag = soup.find('table', class_='tableFile', summary='Data Files')
rows = table_tag.find_all('tr')
for row in rows:
    cells = row.find_all('td')
    if len(cells) > 3:
        if 'INS' in cells[3].text:
            xbrl_link = 'https://www.sec.gov' + cells[2].a['href']
# Obtain XBRL text from document
xbrl_resp = requests.get(xbrl_link)
xbrl_str = xbrl_resp.text
# Find and print stockholder's equity
soup = BeautifulSoup(xbrl_str, 'lxml')
tag_list = soup.find_all()

test = pd.DataFrame()

for tag in tag_list:


    #Added to find All 
    if tag.name.find('us-gaap:') != -1:
        try: 
            if float(tag.text) > 0:
                i = [f'{tag.name}', tag.text]
                i_series = pd.Series(i)
                test = test.append(i_series, ignore_index = True)
        except ValueError:
            pass
        
test.to_csv('test', index= False)
test[test[0].str.contains('asset')]
# Out:
# <td>2015-07-22</td>
# <td>2015-04-28</td>
# <td>2015-01-28</td>
# <td>2014-07-23</td>
# <td>2014-04-24</td>
# <td>2014-01-28</td>
# <td>2013-07-24</td>
# <td>2013-04-24</td>
# <td>2013-01-24</td>
# <td>2012-07-25</td>
# <td>2012-04-25</td>
# <td>2012-01-25</td>
# <td>2011-07-20</td>
# <td>2011-04-21</td>
# <td>2011-01-19</td>
# <td>2010-07-21</td>
# <td>2010-04-21</td>
# <td>2010-01-25</td>
# <td>2009-07-22</td>
# <td>2009-04-27</td>
# <td>2009-04-23</td>
# <td>2009-01-23</td>
# <td>2008-07-23</td>
# <td>2008-05-01</td>
# <td>2008-02-01</td>
# <td>2007-08-08</td>
# <td>2007-05-10</td>
# <td>2007-02-02</td>
# <td>2006-12-29</td>
# <td>2006-05-05</td>
# <td>2006-02-03</td>
# <td>2005-08-03</td>
# <td>2005-05-04</td>
# <td>2005-02-01</td>
# <td>2004-08-05</td>
# <td>2004-05-06</td>
# <td>2004-02-10</td>
# <td>2003-08-12</td>
# <td>2003-05-13</td>
# <td>2003-02-10</td>
#                                                      0             1
# 33   us-gaap:finitelivedintangibleassetsaccumulated...    3371000000
# 49      us-gaap:deferredtaxassetsliabilitiesnetcurrent    5046000000
# 55   us-gaap:indefinitelivedintangibleassetsexcludi...     100000000
# 57              us-gaap:finitelivedintangibleassetsnet    4270000000
# 62                                      us-gaap:assets  261894000000
# 69        us-gaap:intangibleassetsnetexcludinggoodwill    4370000000
# 70                          us-gaap:otherassetscurrent   13635000000
# 71                       us-gaap:otherassetsnoncurrent    3608000000
# 72                               us-gaap:assetscurrent   83403000000
# 73            us-gaap:finitelivedintangibleassetsgross    7641000000
# 82        us-gaap:derivativefairvalueofderivativeasset     501000000
# 84        us-gaap:derivativefairvalueofderivativeasset    3561000000
# 85        us-gaap:derivativefairvalueofderivativeasset     201000000
# 135       us-gaap:derivativefairvalueofderivativeasset    4062000000
# 136       us-gaap:derivativefairvalueofderivativeasset     201000000
# 231  us-gaap:finitelivedintangibleassetsaccumulated...    3085000000
# 246     us-gaap:deferredtaxassetsliabilitiesnetcurrent    4318000000
# 251  us-gaap:indefinitelivedintangibleassetsexcludi...     100000000
# 253             us-gaap:finitelivedintangibleassetsnet    4042000000
# 258                                     us-gaap:assets  231839000000
# 264       us-gaap:intangibleassetsnetexcludinggoodwill    4142000000
# 265                         us-gaap:otherassetscurrent    9806000000
# 266                      us-gaap:otherassetsnoncurrent    3764000000
# 267                              us-gaap:assetscurrent   68531000000
# 268           us-gaap:finitelivedintangibleassetsgross    7127000000
# 277       us-gaap:derivativefairvalueofderivativeasset     222000000
# 279       us-gaap:derivativefairvalueofderivativeasset    1332000000
# 280       us-gaap:derivativefairvalueofderivativeasset      81000000
# 328       us-gaap:derivativefairvalueofderivativeasset    1554000000
# 329       us-gaap:derivativefairvalueofderivativeasset      81000000
# 419     us-gaap:increasedecreaseinotheroperatingassets     319000000
# 429          us-gaap:paymentstoacquireintangibleassets      59000000
# 498     us-gaap:increasedecreaseinotheroperatingassets    1648000000
# 508          us-gaap:paymentstoacquireintangibleassets      48000000
